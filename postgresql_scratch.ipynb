# %%
import psycopg2
import env
import pandas as pd
import acquire

# %%
df = acquire.addresses()

# %%
df
# Out:
#                                                address  \
# 0    7638 Locust St.                               ...
# 1    348 Foxrun Avenue                             ...
# 2    94 Lake Rd.                                   ...
# 3    154 Gates St.                                 ...
# 4    41 West Myrtle St.                            ...
# ..                                                 ...
# 195  27 Vine Court                                 ...
# 196  72 East Miles Ave.                            ...
# 197  7697 West Fifth Ave.                          ...
# 198  7617 High Lane                                ...
# 199  9151 Woodsman St.                             ...
#
#                                                   city state          zipcode  \
# 0    Wilmington                                    ...    MA  1887
# 1    Sandusky                                      ...    OH  44870
# 2    Leominster                                    ...    MA  1453
# 3    Titusville                                    ...    FL  32780
# 4    Hernando                                      ...    MS  38632
# ..                                                 ...   ...              ...
# 195  Moorhead                                      ...    MN  56560
# 196  Kansas City                                   ...    MO  64151
# 197  Ossining                                      ...    NY  10562
# 198  Chillicothe                                   ...    OH  45601
# 199  Elk Grove Village                             ...    IL  60007
#
#                                                  email  \
# 0    hllam@yahoo.com                               ...
# 1    campware@outlook.com                          ...
# 2    aracne@verizon.net                            ...
# 3    jfreedma@verizon.net                          ...
# 4    sinclair@me.com                               ...
# ..                                                 ...
# 195  evilopie@att.net                              ...
# 196  kudra@verizon.net                             ...
# 197  pdbaby@hotmail.com                            ...
# 198  library@yahoo.com                             ...
# 199  fatelk@icloud.com                             ...
#
#                                             first_name  \
# 0    Cassidy                                       ...
# 1    Angela                                        ...
# 2    Lucille                                       ...
# 3    Brogan                                        ...
# 4    Kristin                                       ...
# ..                                                 ...
# 195  Asa                                           ...
# 196  Deacon                                        ...
# 197  Stephen                                       ...
# 198  Daniela                                       ...
# 199  Maurice                                       ...
#
#                                              last_name
# 0    Horn                                          ...
# 1    Bennett                                       ...
# 2    Hoover                                        ...
# 3    Villa                                         ...
# 4    Ramirez                                       ...
# ..                                                 ...
# 195  Lynn                                          ...
# 196  Garrison                                      ...
# 197  Barron                                        ...
# 198  Byrd                                          ...
# 199  Blair                                         ...
#
# [200 rows x 7 columns]

# %%
# try:
#     connection = psycopg2.connect(user='jefferyroeder',
#                                   password=env.password,
#                                   host="127.0.0.1",
#                                   port="5432",
#                                   database="jefferyroeder")
    
#     cursor = connection.cursor()
#     #print postgresql connection properties
#     print(connection.get_dsn_parameters(),"\n")
    
#     #print postgresql version
#     cursor.execute("SELECT version();")
#     record = cursor.fetchone()
#     print("You are connected to - ", record, "\n")
    
# except (Exception, psycopg2.Error) as error :
#     print ("Error while connecting to PostgreSQL", error)
# finally:
#     #closing database connection.
#         if(connection):
#             cursor.close()
#             connection.close()
#             print("PostgreSQL connection is closed")

# %%
df
